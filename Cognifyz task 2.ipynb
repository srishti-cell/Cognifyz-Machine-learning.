# %%
# importing libraries and dataset
import pandas as pd
df = pd.read_csv("Dataset.csv")
df["Cuisines"]=df["Cuisines"].fillna("Unknown")
rows,columns = df.shape
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# there are some coloumn values which has some invalid characters "?"
accented_columns = ['Restaurant Name','City','Address','Locality','Locality Verbose','Cuisines']
from unidecode import unidecode
def clean_text(text):
    if isinstance(text,str):
        return unidecode(text)
    return text
df[accented_columns]=df[accented_columns].applymap(clean_text)
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code     City  \
# 9546        5915730               Naml1 Gurme           208  stanbul
# 9547        5908749                Ceviz Aac1           208  stanbul
# 9548        5915807                     Huqqa           208  stanbul
# 9549        5916112                  Ak Kahve           208  stanbul
# 9550        5927402  Walter's Coffee Roastery           208  stanbul
#
#                                                 Address  Locality  \
# 9546  Kemanke Karamustafa Paa Mahallesi, R1ht1m Cadd...   Karak_y
# 9547  Kouyolu Mahallesi, Muhittin st_nda Caddesi, No...   Kouyolu
# 9548  Kuru_eme Mahallesi, Muallim Naci Caddesi, No 5...  Kuru_eme
# 9549  Kuru_eme Mahallesi, Muallim Naci Caddesi, No 6...  Kuru_eme
# 9550  Cafeaa Mahallesi, Bademalt1 Sokak, No 21/B, Ka...      Moda
#
#        Locality Verbose  Longitude   Latitude  \
# 9546   Karak_y, stanbul  28.977392  41.022793
# 9547   Kouyolu, stanbul  29.041297  41.009847
# ...

# %%
# exporting the cleaned dataset
SD = df.to_csv("cleaned1.csv",index=False)

# %% [markdown]
# # Resturant Recommendation with Cuisines

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df1 = pd.read_csv("cleaned1.csv")
rows,columns = df1.shape

# Display the DataFrame
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# Read the CSV file into a DataFrame
df1 = pd.read_csv("cleaned1.csv")

# Extracting features
y = df1['Restaurant Name']
x_text = df1['Cuisines'] + " " + df1['Rating color'] + " " + df1['Rating text'] + " " + df1["Votes"].astype(str) + " " + df1["Price range"].astype(str)

# Create a TF-IDF vectorizer
tfidf = TfidfVectorizer()

# Transform the text data using TF-IDF
x = tfidf.fit_transform(x_text)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarityScore = cosine_similarity(x)
similarityScore
# Out:
# array([[1.        , 0.42113843, 0.04186458, ..., 0.        , 0.04188754,
#         0.05554734],
#        [0.42113843, 1.        , 0.04931748, ..., 0.        , 0.04934452,
#         0.65120488],
#        [0.04186458, 0.04931748, 1.        , ..., 0.01981244, 0.11616055,
#         0.15404129],
#        ...,
#        [0.        , 0.        , 0.01981244, ..., 1.        , 0.01982331,
#         0.02628782],
#        [0.04188754, 0.04934452, 0.11616055, ..., 0.01982331, 1.        ,
#         0.24058858],
#        [0.05554734, 0.65120488, 0.15404129, ..., 0.02628782, 0.24058858,
#         1.        ]])

# %%
userInput = input("Enter Your Preferred Cuisines :")
cuisineList = df1["Cuisines"]
for i in range(len(cuisineList)):
    if userInput in cuisineList[i]:
        k = df1.iloc[i]['Restaurant Name']
        index = i
        break
RecommendationScore = list(enumerate(similarityScore[index]))
# Out:
# Enter Your Preferred Cuisines :Japanese

# %%
# Recommendation of Resturant
sortedResturantList = sorted(RecommendationScore,key=lambda x:x[1],reverse = True)
count = 0
i=0
for rest in sortedResturantList:
    Index = rest[0]
    k=df1.iloc[Index]["Restaurant Name"]
    print(k)
    count+=1
    
    if count==10:
        break
    i+=1
# Out:
# Le Petit Souffle
# Zen Japanese Steakhouse and Sushi Bar
# Kake Di Hatti
# Restaurant Mosaic @ The Orient
# Sushi Leblon
# Restaurant Gordon Ramsay
# Tokyo Mon Amour
# Baba Au Rhum
# La Plage
# Les 3 Brasseurs
